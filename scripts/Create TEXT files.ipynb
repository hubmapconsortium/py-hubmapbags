# %% [markdown]
# # Create TXT files
# ## Create folder and copy definitions

# %%
import pandas as pd
from shutil import copytree
from shutil import rmtree
import pathlib
import json
import yaml
import hubmapbags
from pathlib import Path
import pandas as pd
from tqdm import tqdm
from warnings import warn as warning
from datetime import datetime

instance = 'prod'
token = ''

# %%
now = datetime.now()
output_directory = 'data'
if not Path(output_directory).exists():
    Path(output_directory).mkdir()

report_output_directory = 'uuid-protected-data-report'
if not Path(report_output_directory).exists():
    Path(report_output_directory).mkdir()

report_output_filename = report_output_directory + '/' + str(now.strftime('%Y%m%d')) + '.pkl'
print('File found on disk. Loading ' + report_output_filename + '.')
report = pd.read_pickle(report_output_filename.replace('tsv', 'pkl'))
# Out:
# File found on disk. Loading uuid-protected-data-report/20230104.pkl.

# %%
def get_dbgap_study_id( datum ):
        if ( datum['group_name'] == 'University of California San Diego TMC' ) or \
                ( datum['group_name'] == 'Broad Institute RTI' and datum['data_type'] == 'Slide-seq' ):
                return 'phs002249'
        elif datum['group_name'] == 'Stanford TMC':
                return 'phs002272'
        else:
                return None

# %%
report
# Out:
#                                 uuid        hubmap_id     status  \
# 0   620e742ae8401461013804e8abf1a56a  HBM975.DJNJ.667  Published
# 1   c2778cdd0a18e6f1ca755cbf65511aed  HBM733.SLXV.683  Published
# 2   34d3a6eeb06ddc1681c788113e66d52d  HBM473.HNPK.434  Published
# 3   4e1da648c2a1451edba33d991dc163ab  HBM563.PTWZ.467  Published
# 4   bca3d31804ecc8be096d0b7691419335  HBM688.DRXP.369  Published
# ..                               ...              ...        ...
# 12  0186092a96f773bafb62721eb4399c6b  HBM577.NRCL.952  Published
# 13  166ea9ac6dbfa53966c60176b92d35ca  HBM243.QRKL.558  Published
# 14  d859a8c563558b7db0b73c6170ad84fd  HBM893.LCWM.423  Published
# 15  0b10c4d5df6cb25fa12a67f7e72580ab  HBM848.VLZL.329  Published
# 16  c3fa09a6a84e40730bb3948ea733b3e9  HBM393.DSCC.392  Published
#
#     is_protected     data_type  \
# 0           True  ATACseq-bulk
# 1           True  ATACseq-bulk
# 2           True  ATACseq-bulk
# 3           True  ATACseq-bulk
# 4           True  ATACseq-bulk
# ..           ...           ...
# 12          True           WGS
# 13          True           WGS
# 14          True           WGS
# 15          True           WGS
# 16          True           WGS
#
#                                             directory    group_name has_uuids  \
# 0   /hive/hubmap/data/protected/Stanford TMC/620e7...  Stanford TMC      True
# 1   /hive/hubmap/data/protected/Stanford TMC/c2778...  Stanford TMC      True
# 2   /hive/hubmap/data/protected/Stanford TMC/34d3a...  Stanford TMC      True
# 3   /hive/hubmap/data/protected/Stanford TMC/4e1da...  Stanford TMC      True
# 4   /hive/hubmap/data/protected/Stanford TMC/bca3d...  Stanford TMC      True
# ..                                                ...           ...       ...
# 12  /hive/hubmap/data/protected/Stanford TMC/01860...  Stanford TMC      True
# 13  /hive/hubmap/data/protected/Stanford TMC/166ea...  Stanford TMC      True
# 14  /hive/hubmap/data/protected/Stanford TMC/d859a...  Stanford TMC      True
# 15  /hive/hubmap/data/protected/Stanford TMC/0b10c...  Stanford TMC      True
# 16  /hive/hubmap/data/protected/Stanford TMC/c3fa0...  Stanford TMC      True
#
#    number_of_uuids number_of_files
# 0                3               3
# 1                3               3
# 2                3               3
# 3                3               3
# 4                3               3
# ..             ...             ...
# 12               3               3
# 13               7               7
# 14               3               3
# 15               3               3
# 16              11              11
#
# [417 rows x 10 columns]

# %%
report['dbgap_study_id'] = None
for index, datum in tqdm(report.iterrows()):
    report.loc[index,'dbgap_study_id'] = get_dbgap_study_id( datum )
    
report = report[report['dbgap_study_id'] == 'phs002249']
report
# Out:
# 417it [00:00, 5364.25it/s]
#                                 uuid        hubmap_id     status  \
# 17  74c08831f6c89b35d6df46bf88c3fbf0  HBM784.RVTS.872  Published
# 18  16782d78da92510a67880e719af368f7  HBM762.VLJF.655  Published
# 20  6aa7ff3bf38a6b1a242b6d7d3198f44a  HBM624.BLKG.259  Published
# 22  059d18392b5a8805337a0c8ef5d19b46  HBM455.ZPNN.623  Published
# 26  53f81503913a841f57f07835ce94a5b9  HBM929.ZQRZ.278  Published
# ..                               ...              ...        ...
# 34  81090ae60d3b903dfb5b3e6f461dc96c  HBM786.LZQZ.242  Published
# 35  d3e8350bdcc7a5851deb22045c3af31a  HBM348.FXGT.728  Published
# 36  69b3d856a476114c1819287d0d688387  HBM969.VBPS.239  Published
# 37  7654bacb99511aaaa669bf4e623b5baf  HBM876.NMKV.392  Published
# 39  2fc79a0ddab0e95d5935b3234f5cf372  HBM543.DWSW.978  Published
#
#     is_protected       data_type  \
# 17          True  SNARE-ATACseq2
# 18          True  SNARE-ATACseq2
# 20          True  SNARE-ATACseq2
# 22          True  SNARE-ATACseq2
# 26          True  SNARE-ATACseq2
# ..           ...             ...
# 34          True       Slide-seq
# 35          True       Slide-seq
# 36          True       Slide-seq
# 37          True       Slide-seq
# 39          True       Slide-seq
#
#                                             directory  \
# 17  /hive/hubmap/data/protected/University of Cali...
# 18  /hive/hubmap/data/protected/University of Cali...
# 20  /hive/hubmap/data/protected/University of Cali...
# 22  /hive/hubmap/data/protected/University of Cali...
# 26  /hive/hubmap/data/protected/University of Cali...
# ..                                                ...
# 34  /hive/hubmap/data/protected/Broad Institute RT...
# 35  /hive/hubmap/data/protected/Broad Institute RT...
# 36  /hive/hubmap/data/protected/Broad Institute RT...
# 37  /hive/hubmap/data/protected/Broad Institute RT...
# 39  /hive/hubmap/data/protected/Broad Institute RT...
#
#                                 group_name has_uuids number_of_uuids  \
# 17  University of California San Diego TMC      True               5
# 18  University of California San Diego TMC      True               4
# 20  University of California San Diego TMC      True               4
# 22  University of California San Diego TMC      True               5
# 26  University of California San Diego TMC      True               4
# ..                                     ...       ...             ...
# 34                     Broad Institute RTI      True              14
# 35                     Broad Institute RTI      True              14
# 36                     Broad Institute RTI      True              14
# 37                     Broad Institute RTI      True              14
# 39                     Broad Institute RTI      True              14
#
#    number_of_files dbgap_study_id
# 17               5      phs002249
# 18               4      phs002249
# 20               4      phs002249
# 22               5      phs002249
# 26               4      phs002249
# ..             ...            ...
# 34              14      phs002249
# 35              14      phs002249
# 36              14      phs002249
# 37              14      phs002249
# 39              14      phs002249
#
# [179 rows x 11 columns]

# %%
def build_dataframe( report, instance=instance, token=token ):
    headers = ['donor_uuid','donor_hubmap_id',\
           'direct_sample_uuid','direct_sample_hubmap_id',\
           'organ_uuid','organ_hubmap_id','organ_type',\
           'direct_sample_type','dataset_metadata','donor_metadata']
        
    for index, datum in tqdm(report.iterrows()):
        pmetadata = hubmapbags.apis.get_provenance_info( datum['hubmap_id'], instance=instance, token=token)
        
        try:
            report.loc[index,'donor_uuid'] = pmetadata['donor_uuid'][0]
        except Exception as e:
            print(e)
            print(pmetadata['donor_uuid'])
            
        try:
            report.loc[index,'donor_hubmap_id'] = pmetadata['donor_hubmap_id'][0]
        except Exception as e:
            print(e)
            print(pmetadata['donor_hubmap_id'])
        
        report.loc[index,'direct_sample_uuid'] = pmetadata['first_sample_uuid'][0]
        report.loc[index,'direct_sample_type'] = pmetadata['first_sample_type'][0]
        report.loc[index,'direct_sample_hubmap_id'] = pmetadata['first_sample_hubmap_id'][0]
        
        try:
            report.loc[index,'organ_uuid'] = pmetadata['organ_uuid'][0]
        except Exception as e:
            print(e)
            print(pmetadata['organ_uuid'])
        
        try:
            report.loc[index,'organ_hubmap_id'] = pmetadata['organ_hubmap_id'][0]
        except Exception as e:
            print(e)
            print(pmetadata['organ_hubmap_id'])
            
        try:
            report.loc[index,'organ_type'] = pmetadata['organ_type'][0]
        except Exception as e:
            print(e)
            print(pmetadata['organ_type'])
        
        metadata = hubmapbags.apis.get_dataset_info( datum['hubmap_id'], instance=instance, token=token )
        
        try:
            report.loc[index,'donor_uuid'] = pmetadata.get('donor_uuid')[0]
        except Exception as e:
            print(e)
            print(pmetadata.get('donor_uuid'))
            
        try:
            report.loc[index,'donor_hubmap_id'] = pmetadata.get('donor_hubmap_id')[0]
        except Exception as e:
            print(e)
            print(pmetadata.get('donor_hubmap_id'))
    
    return report

# %%
report = build_dataframe( report, instance=instance, token=token )
report.to_csv( 'dbgap.' + str(now.strftime('%Y%m%d')) + '.tsv', sep='\t', index=False)
# Out:
# 0it [00:00, ?it/s]/tmp/ipykernel_240558/2960983605.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'donor_uuid'] = pmetadata['donor_uuid'][0]
# /tmp/ipykernel_240558/2960983605.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'donor_hubmap_id'] = pmetadata['donor_hubmap_id'][0]
# /tmp/ipykernel_240558/2960983605.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'direct_sample_uuid'] = pmetadata['first_sample_uuid'][0]
# /tmp/ipykernel_240558/2960983605.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'direct_sample_type'] = pmetadata['first_sample_type'][0]
# /tmp/ipykernel_240558/2960983605.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'direct_sample_hubmap_id'] = pmetadata['first_sample_hubmap_id'][0]
# /tmp/ipykernel_240558/2960983605.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'organ_uuid'] = pmetadata['organ_uuid'][0]
# /tmp/ipykernel_240558/2960983605.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'organ_hubmap_id'] = pmetadata['organ_hubmap_id'][0]
# /tmp/ipykernel_240558/2960983605.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.loc[index,'organ_type'] = pmetadata['organ_type'][0]
# 179it [00:55,  3.22it/s]

# %%
report = report[(report['group_name'] == 'University of California San Diego TMC') | (report['group_name'] == 'Broad Institute RTI')]

# %%
report
# Out:
#                                 uuid        hubmap_id     status  \
# 17  74c08831f6c89b35d6df46bf88c3fbf0  HBM784.RVTS.872  Published
# 18  16782d78da92510a67880e719af368f7  HBM762.VLJF.655  Published
# 20  6aa7ff3bf38a6b1a242b6d7d3198f44a  HBM624.BLKG.259  Published
# 22  059d18392b5a8805337a0c8ef5d19b46  HBM455.ZPNN.623  Published
# 26  53f81503913a841f57f07835ce94a5b9  HBM929.ZQRZ.278  Published
# ..                               ...              ...        ...
# 34  81090ae60d3b903dfb5b3e6f461dc96c  HBM786.LZQZ.242  Published
# 35  d3e8350bdcc7a5851deb22045c3af31a  HBM348.FXGT.728  Published
# 36  69b3d856a476114c1819287d0d688387  HBM969.VBPS.239  Published
# 37  7654bacb99511aaaa669bf4e623b5baf  HBM876.NMKV.392  Published
# 39  2fc79a0ddab0e95d5935b3234f5cf372  HBM543.DWSW.978  Published
#
#     is_protected       data_type  \
# 17          True  SNARE-ATACseq2
# 18          True  SNARE-ATACseq2
# 20          True  SNARE-ATACseq2
# 22          True  SNARE-ATACseq2
# 26          True  SNARE-ATACseq2
# ..           ...             ...
# 34          True       Slide-seq
# 35          True       Slide-seq
# 36          True       Slide-seq
# 37          True       Slide-seq
# 39          True       Slide-seq
#
#                                             directory  \
# 17  /hive/hubmap/data/protected/University of Cali...
# 18  /hive/hubmap/data/protected/University of Cali...
# 20  /hive/hubmap/data/protected/University of Cali...
# 22  /hive/hubmap/data/protected/University of Cali...
# 26  /hive/hubmap/data/protected/University of Cali...
# ..                                                ...
# 34  /hive/hubmap/data/protected/Broad Institute RT...
# 35  /hive/hubmap/data/protected/Broad Institute RT...
# 36  /hive/hubmap/data/protected/Broad Institute RT...
# 37  /hive/hubmap/data/protected/Broad Institute RT...
# 39  /hive/hubmap/data/protected/Broad Institute RT...
#
#                                 group_name has_uuids number_of_uuids  \
# 17  University of California San Diego TMC      True               5
# 18  University of California San Diego TMC      True               4
# 20  University of California San Diego TMC      True               4
# 22  University of California San Diego TMC      True               5
# 26  University of California San Diego TMC      True               4
# ..                                     ...       ...             ...
# 34                     Broad Institute RTI      True              14
# 35                     Broad Institute RTI      True              14
# 36                     Broad Institute RTI      True              14
# 37                     Broad Institute RTI      True              14
# 39                     Broad Institute RTI      True              14
#
#    number_of_files dbgap_study_id                        donor_uuid  \
# 17               5      phs002249  1e0b527a436936050455fe755dfbaba2
# 18               4      phs002249  e3d3717ad581030c03bed6641d76e088
# 20               4      phs002249  ab8258a97e0820c294d1f0ba2d261f61
# 22               5      phs002249  ab8258a97e0820c294d1f0ba2d261f61
# 26               4      phs002249  e3d3717ad581030c03bed6641d76e088
# ..             ...            ...                               ...
# 34              14      phs002249  1e0b527a436936050455fe755dfbaba2
# 35              14      phs002249  e3d3717ad581030c03bed6641d76e088
# 36              14      phs002249  ab8258a97e0820c294d1f0ba2d261f61
# 37              14      phs002249  ab8258a97e0820c294d1f0ba2d261f61
# 39              14      phs002249  ab8258a97e0820c294d1f0ba2d261f61
#
#     donor_hubmap_id                direct_sample_uuid      direct_sample_type  \
# 17  HBM735.QDFT.264  0a558711c6b9d5b9029717d722a2c31c  fresh_frozen_oct_block
# 18  HBM735.BNLK.837  883a77f2057d6ac7c564c6b29f6844ed                   other
# 20  HBM984.MHHN.738  1591f63f0efe8a1360112e45349fa242                   other
# 22  HBM984.MHHN.738  69dae161de204ab790321a3617083aee                   other
# 26  HBM735.BNLK.837  72e1fcc1caa93ae48cdd4bb7c988696b                   other
# ..              ...                               ...                     ...
# 34  HBM735.QDFT.264  0a558711c6b9d5b9029717d722a2c31c  fresh_frozen_oct_block
# 35  HBM735.BNLK.837  1bd881fda3d55d9c0f3619eb9b1edc8a                   other
# 36  HBM984.MHHN.738  af7ba388bfa0bffae56a0bf0539d1165                   other
# 37  HBM984.MHHN.738  1d74e463b20ff587e01762d2490283b0                   other
# 39  HBM984.MHHN.738  b026cf619c7bc1a4399f794447c1945f                   other
#
#    direct_sample_hubmap_id                        organ_uuid  organ_hubmap_id  \
# 17         HBM964.XZCR.478  7219d978053995b9e004321187352519  HBM656.RWNC.696
# 18         HBM424.SZPT.976  d9cf9a42d61f67ce917d27b5c7df0826  HBM243.FFSQ.593
# 20         HBM752.TSBJ.328  3523bf7c6d28255e5667a355c2038e05  HBM294.MVVV.724
# 22         HBM964.LPPQ.663  3523bf7c6d28255e5667a355c2038e05  HBM294.MVVV.724
# 26         HBM837.JPCL.782  d9cf9a42d61f67ce917d27b5c7df0826  HBM243.FFSQ.593
# ..                     ...                               ...              ...
# 34         HBM964.XZCR.478  7219d978053995b9e004321187352519  HBM656.RWNC.696
# 35         HBM548.DGFD.379  d9cf9a42d61f67ce917d27b5c7df0826  HBM243.FFSQ.593
# 36         HBM363.WBDM.628  3523bf7c6d28255e5667a355c2038e05  HBM294.MVVV.724
# 37         HBM828.GVQJ.749  3523bf7c6d28255e5667a355c2038e05  HBM294.MVVV.724
# 39         HBM829.QGJB.974  3523bf7c6d28255e5667a355c2038e05  HBM294.MVVV.724
#
#         organ_type
# 17  kidney (right)
# 18   kidney (left)
# 20   kidney (left)
# 22   kidney (left)
# 26   kidney (left)
# ..             ...
# 34  kidney (right)
# 35   kidney (left)
# 36   kidney (left)
# 37   kidney (left)
# 39   kidney (left)
#
# [158 rows x 19 columns]

# %%
#DISCLAIMER: @icaoberg this code is super alpha. Please be kind.
# remove submission folder if it exists
directory = 'phs002249'
p = pathlib.Path( directory )
if p.exists() and p.is_dir():
    print( 'Removing existing folder ' + directory )
    rmtree(p)
result = copytree( 'dbgap-submission-scripts/templates', directory )
print(directory)
# Out:
# Removing existing folder phs002249
# phs002249

# %% [markdown]
# ## Subject Consent

# %%
donor = report[['donor_hubmap_id', 'donor_uuid']]
donor = donor.drop_duplicates(subset=['donor_hubmap_id'])

donor['sex'] = None
for index, datum in tqdm(donor.iterrows()):
    metadata = hubmapbags.apis.get_entity_info( datum['donor_hubmap_id'], token=token, instance='prod' )
    if 'living_donor_data' in metadata['metadata'].keys():
        for info in metadata['metadata']['living_donor_data']:
            if info['grouping_concept_preferred_term'] == 'Sex':
                donor.loc[index,'sex'] = info['preferred_term']
    else:
        for info in metadata['metadata']['organ_donor_data']:
            if info['grouping_concept_preferred_term'] == 'Sex':
                donor.loc[index,'sex'] = info['preferred_term']
                
    if donor.loc[index,'sex'] == 'Male':
        donor.loc[index,'sex'] = 1;
    else:
        donor.loc[index,'sex'] = 2;
        
    donor.loc[index,'subject_source']='HuBMAP'
    
donor = donor.drop('donor_uuid',axis=1)
donor['SOURCE_SUBJECT_ID']=donor['donor_hubmap_id']
donor['consent']=1
donor = donor.rename(columns={'donor_hubmap_id':'SUBJECT_ID','consent':'CONSENT','sex':'SEX', 'subject_source':'SUBJECT_SOURCE'})
donor=donor.reindex(columns=['SUBJECT_ID', 'CONSENT', 'SEX', 'SUBJECT_SOURCE', 'SOURCE_SUBJECT_ID'])
donor.to_csv(directory + '/2a_SubjectConsent_DS.txt', index=False, sep='\t')

donor
# Out:
# 10it [00:00, 12.50it/s]
#          SUBJECT_ID  CONSENT SEX SUBJECT_SOURCE SOURCE_SUBJECT_ID
# 17  HBM735.QDFT.264        1   1         HuBMAP   HBM735.QDFT.264
# 18  HBM735.BNLK.837        1   2         HuBMAP   HBM735.BNLK.837
# 20  HBM984.MHHN.738        1   1         HuBMAP   HBM984.MHHN.738
# 40  HBM584.TVKC.257        1   2         HuBMAP   HBM584.TVKC.257
# 41  HBM464.FJWN.992        1   1         HuBMAP   HBM464.FJWN.992
# 44  HBM289.BLHF.363        1   2         HuBMAP   HBM289.BLHF.363
# 50  HBM943.SCQQ.877        1   1         HuBMAP   HBM943.SCQQ.877
# 60  HBM485.KRGM.628        1   1         HuBMAP   HBM485.KRGM.628
# 67  HBM277.DBXJ.256        1   2         HuBMAP   HBM277.DBXJ.256
# 76  HBM477.DBJN.952        1   1         HuBMAP   HBM477.DBJN.952

# %% [markdown]
# ## Sample Attributes

# %%
with open('search-api/src/search-schema/data/definitions/enums/organ_types.yaml') as file:
    organ_types = yaml.load(file, Loader=yaml.FullLoader)

sample_attributes = report[['dataset_hubmap_id','dataset_metadata']]

analyte_class = []
for index in range(len(sample_attributes)):
    metadata = sample_attributes.loc[index]['dataset_metadata']
    try:
        analyte_class.append( metadata[metadata.find('analyte_class',0)+16: \
                         metadata.find(',',metadata.find('analyte_class',0))])
    except:
        analyte_class.append('MISSING')
    
sample_attributes = sample_attributes.drop('dataset_metadata',axis=1)
sample_attributes['ANALYTE_TYPE'] = analyte_class
sample_attributes.insert(1,'BODY_SITE',df['organ_type'])
#sample_attributes.insert(1,'HISTOLOGICAL_TYPE',df['organ_type'])
sample_attributes.insert(3,'IS_TUMOR',['N']*len(sample_attributes))

for index in range(len(sample_attributes)):
    sample_attributes['BODY_SITE'].loc[index] = organ_types[sample_attributes['BODY_SITE'].loc[index]]['description']
    #sample_attributes['HISTOLOGICAL_TYPE'].loc[index] = organ_types[sample_attributes['HISTOLOGICAL_TYPE'].loc[index]]['description']

sample_attributes = sample_attributes.drop_duplicates(subset=['dataset_hubmap_id'])
sample_attributes = sample_attributes.rename(columns={'dataset_hubmap_id':'SAMPLE_ID'})

#sample_attributes=sample_attributes.reindex(columns=['TMC', 'SAMPLE_ID', 'BODY_SITE', 'ANALYTE_TYPE', 'IS_TUMOR', 'HISTOLOGICAL_TYPE'])
sample_attributes=sample_attributes.reindex(columns=['TMC', 'SAMPLE_ID', 'BODY_SITE', 'ANALYTE_TYPE', 'IS_TUMOR'])
#sample_attributes['HISTOLOGICAL_TYPE'].replace('Lymph Node 05', 'Lymph Node', inplace=True)
#sample_attributes['HISTOLOGICAL_TYPE'].replace('Lymph Node 01', 'Lymph Node', inplace=True)
sample_attributes['BODY_SITE'].replace('Lymph Node 05', 'Lymph Node', inplace=True)
sample_attributes['BODY_SITE'].replace('Lymph Node 01', 'Lymph Node', inplace=True)

print(sample_attributes)

for tmc_name in tmc.unique():
    temp = sample_attributes
    temp = temp[temp.TMC.isin([tmc_name])]
    temp = temp.drop('TMC',axis=1)
    temp.to_csv('submission-' + tmc_name + '/6a_SampleAttributes_DS.txt', index=False, sep='\t')

# %% [markdown]
# ## Subject Sample Mapping (SSM)

# %%
sample_mapping = df[['donor_hubmap_id','dataset_hubmap_id']]
sample_mapping.insert(0,'TMC',tmc)
sample_mapping = sample_mapping.drop_duplicates(subset=['dataset_hubmap_id'])
sample_mapping = sample_mapping.rename(columns={'donor_hubmap_id':'SUBJECT_ID','dataset_hubmap_id':'SAMPLE_ID'})
print( sample_mapping )

for tmc_name in tmc.unique():
    temp = sample_mapping
    temp = temp[temp.TMC.isin([tmc_name])]
    temp = temp.drop('TMC',axis=1)
    temp.to_csv('submission-' + tmc_name + '/3a_SSM_DS.txt', index=False, sep='\t')

# %%
report.keys()

# %%
datum

# %%
metadata = hubmapbags.apis.get_dataset_info( 'HBM455.ZPNN.623', instance='prod', token=token )

# %%
metadata

# %%
metadata = hubmapbags.apis.get_provenance_info( 'HBM784.RVTS.872', instance='prod', token=token)

# %%
metadata

# %%
metadata = hubmapbags.apis.get_entity_info( 'HBM943.SCQQ.877', instance='prod', token=token)

# %%
metadata
# Out:
# {'created_by_user_displayname': 'GLORIA PRYHUBER',
#  'created_by_user_email': 'gloria_pryhuber@urmc.rochester.edu',
#  'created_by_user_sub': '8c53bc92-07c5-4e1b-b9a0-0a4754ec874b',
#  'created_timestamp': 1597681398391,
#  'data_access_level': 'public',
#  'description': '37 yr old black male with intracranial hemorrhage and hypertension',
#  'entity_type': 'Donor',
#  'group_name': 'University of California San Diego TMC',
#  'group_uuid': '03b3d854-ed44-11e8-8bce-0e368f3075e8',
#  'hubmap_id': 'HBM943.SCQQ.877',
#  'lab_donor_id': 'D239',
#  'label': 'D239',
#  'last_modified_timestamp': 1597688929120,
#  'last_modified_user_displayname': 'GLORIA PRYHUBER',
#  'last_modified_user_email': 'gloria_pryhuber@urmc.rochester.edu',
#  'last_modified_user_sub': '8c53bc92-07c5-4e1b-b9a0-0a4754ec874b',
#  'metadata': {'organ_donor_data': [{'code': '424144002',
#     'concept_id': 'C0001779',
#     'data_type': 'Numeric',
#     'data_value': '37',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '424144002',
#     'grouping_concept': 'C0001779',
#     'grouping_concept_preferred_term': 'Age',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': 'EQ',
#     'preferred_term': 'Age',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': 'years'},
#    {'code': '413464008',
#     'concept_id': 'C0027567',
#     'data_type': 'Nominal',
#     'data_value': 'Race',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '415229000',
#     'grouping_concept': 'C0034510',
#     'grouping_concept_preferred_term': 'Race',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': '',
#     'preferred_term': 'Black or African American',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': ''},
#    {'code': '10052007',
#     'concept_id': 'C0086582',
#     'data_type': 'Nominal',
#     'data_value': 'Sex',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '57312000',
#     'grouping_concept': 'C1522384',
#     'grouping_concept_preferred_term': 'Sex',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': '',
#     'preferred_term': 'Male',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': ''},
#    {'code': '27113001',
#     'concept_id': 'C0005910',
#     'data_type': 'Numeric',
#     'data_value': '150.9',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '27113001',
#     'grouping_concept': 'C0005910',
#     'grouping_concept_preferred_term': 'Weight',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': 'EQ',
#     'preferred_term': 'Weight',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': 'kg'},
#    {'code': '50373000',
#     'concept_id': 'C0005890',
#     'data_type': 'Numeric',
#     'data_value': '182.88',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '50373000',
#     'grouping_concept': 'C0005890',
#     'grouping_concept_preferred_term': 'Height',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': 'EQ',
#     'preferred_term': 'Height',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': 'cm'},
#    {'code': '230690007',
#     'concept_id': 'C0038454',
#     'data_type': 'Nominal',
#     'data_value': 'Cerebrovascular accident',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '184305005',
#     'grouping_concept': 'C0007465',
#     'grouping_concept_preferred_term': 'Cause of Death',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': '',
#     'preferred_term': 'Cerebrovascular accident',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': ''},
#    {'code': '1386000',
#     'concept_id': 'C0151699',
#     'data_type': 'Nominal',
#     'data_value': 'Intracranial hemorrhage',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '246078001',
#     'grouping_concept': 'C0449413',
#     'grouping_concept_preferred_term': 'Mechanism of Injury',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': '',
#     'preferred_term': 'Intracranial hemorrhage',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': ''},
#    {'code': '38605008',
#     'concept_id': 'C0277610',
#     'data_type': 'Nominal',
#     'data_value': 'Natural causes',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '419620001',
#     'grouping_concept': 'C0011065',
#     'grouping_concept_preferred_term': 'Death Event',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': '',
#     'preferred_term': 'Natural causes',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': ''},
#    {'code': '38341003',
#     'concept_id': 'C0020538',
#     'data_type': 'Nominal',
#     'data_value': 'Hypertension',
#     'end_datetime': '',
#     'graph_version': 'UMLS2022AA',
#     'grouping_code': '392521001',
#     'grouping_concept': 'C0262926',
#     'grouping_concept_preferred_term': 'Medical History',
#     'grouping_sab': 'SNOMEDCT_US',
#     'numeric_operator': '',
#     'preferred_term': 'Hypertension',
#     'sab': 'SNOMEDCT_US',
#     'start_datetime': '',
#     'units': ''}]},
#  'open_consent': 'False',
#  'portal_metadata_upload_files': [{'description': '',
#    'filepath': '/hive/hubmap/data/uploads/03b3d854-ed44-11e8-8bce-0e368f3075e8/4397fcd072ac96299992b47da1dbae64/HuBMAPMetadata_D239_BRINDL2020-08-17_14-25-08.xlsx'}],
#  'protocol_url': 'dx.doi.org/10.17504/protocols.io.bjuxknxn',
#  'submission_id': 'UCSD0015',
#  'uuid': '4397fcd072ac96299992b47da1dbae64'}
